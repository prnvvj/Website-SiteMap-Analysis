# %% [markdown]
# <a href="https://colab.research.google.com/github/prnvvj/Website-SiteMap-Analysis/blob/main/Website_SiteMap_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install advertools
# Out:
# ...
#      |████████████████████████████████| 276kB 23.8MB/s
# ...
#      |████████████████████████████████| 256kB 43.3MB/s
# ...
#      |████████████████████████████████| 3.2MB 44.1MB/s
# ...
#      |████████████████████████████████| 61kB 7.0MB/s
# ...
#      |████████████████████████████████| 256kB 44.1MB/s
# ...
#      |████████████████████████████████| 71kB 7.2MB/s
# ...
#      |████████████████████████████████| 3.1MB 52.1MB/s
# ...
#      |████████████████████████████████| 3.2MB 42.5MB/s
# ...
#      |████████████████████████████████| 81kB 8.2MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-cp37-none-any.whl size=11517 sha256=97efb111a6d97e53781b6bd82dbb194fc28e5d7fefe1717371131eb999f07e4d
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# ...
#   Created wheel for protego: filename=Protego-0.1.16-cp37-none-any.whl size=7766 sha256=4f72894cc3035a83f97bbd9df9db4ab493ca3344458150ed25a866d56ec50523
# ...

# %%
import advertools as adv
import plotly.graph_objects as go
import pandas as pd

# %%
buzzfeed_generic = adv.sitemap_to_df('https://www.buzzfeed.com/sitemap/buzzfeed.xml')
buzzfeed_tasty = adv.sitemap_to_df('https://www.buzzfeed.com/sitemap/tasty.xml')
buzzfeed_video = adv.sitemap_to_df('https://www.buzzfeed.com/sitemap/video.xml')
buzzfeed_shopping = adv.sitemap_to_df('https://www.buzzfeed.com/sitemap/shopping.xml')
# buzzfeed_new = adv.sitemap_to_df('https://www.buzzfeed.com/sitemap.xml')
# Out:
# 2021-04-21 11:46:54,647 | INFO | sitemaps.py:419 | sitemap_to_df | Getting https://www.buzzfeed.com/sitemap/buzzfeed/2008_6.xml
# 2021-04-21 11:46:54,656 | INFO | sitemaps.py:419 | sitemap_to_df | Getting https://www.buzzfeed.com/sitemap/buzzfeed/2008_3.xml
# 2021-04-21 11:46:54,668 | INFO | sitemaps.py:419 | sitemap_to_df | Getting https://www.buzzfeed.com/sitemap/buzzfeed/2008_5.xml
# 2021-04-21 11:46:54,669 | INFO | sitemaps.py:419 | sitemap_to_df | Getting https://www.buzzfeed.com/sitemap/buzzfeed/2008_2.xml
# 2021-04-21 11:46:54,677 | INFO | sitemaps.py:419 | sitemap_to_df | Getting https://www.buzzfeed.com/sitemap/buzzfeed/2008_1.xml
# 2021-04-21 11:46:54,678 | INFO | sitemaps.py:419 | sitemap_to_df | Getting https://www.buzzfeed.com/sitemap/buzzfeed/2008_4.xml
# 2021-04-21 11:46:54,685 | INFO | sitemaps.py:419 | sitemap_to_df | Getting https://www.buzzfeed.com/sitemap/buzzfeed/2008_8.xml
# ...

# %%
buzzfeed = pd.concat([buzzfeed_generic, buzzfeed_tasty, buzzfeed_video, buzzfeed_shopping])

# %%
buzzfeed.sample(5)
# Out:
#                                                       loc  ... video_duration
# 72096   https://www.buzzfeed.com/emilyhennen/32-pictur...  ...            NaN
# 258972  https://www.buzzfeed.com/mx/mireyagonzalez/en-...  ...            NaN
# 114512  https://www.buzzfeed.com/briangalindo/10-times...  ...            NaN
# 316468  https://www.buzzfeed.com/hanifahrahman/movies-...  ...            NaN
# 96669   https://www.buzzfeed.com/justinabarca/i-smell-...  ...            NaN
#
# [5 rows x 11 columns]

# %%
buzzfeed['lastmod'] = pd.to_datetime(buzzfeed['lastmod'])

# %%
buzzfeed = buzzfeed.set_index('lastmod')
buzzfeed.sample(5)
# Out:
#                                                                          loc  ... video_duration
# lastmod                                                                       ...
# 2018-05-12 00:00:00+00:00  https://www.buzzfeed.com/terripous/13-eco-frie...  ...            NaN
# 2020-09-03 00:00:00+00:00  https://www.buzzfeed.com/sylviaobell/dos-and-d...  ...            NaN
# 2012-04-16 00:00:00+00:00  https://www.buzzfeed.com/foodbeast/make-a-dark...  ...            NaN
# 2017-11-03 00:00:00+00:00  https://www.buzzfeed.com/robinedds/genius-brut...  ...            NaN
# 2017-11-30 00:00:00+00:00  https://www.buzzfeed.com/benhenry/rihanna-es-l...  ...            NaN
#
# [5 rows x 10 columns]

# %%
buzzfeed['sitemap_cat'] = buzzfeed['sitemap'].str.split('/').str[4]

# %%
buzzfeed['sitemap_cat'].value_counts(normalize = True) * 100
# Out:
# 2021-04-21 11:48:13,497 | INFO | utils.py:157 | _init_num_threads | NumExpr defaulting to 2 threads.
# buzzfeed    88.903064
# shopping     6.590503
# video        3.473177
# tasty        1.033256
# Name: sitemap_cat, dtype: float64

# %%
buzzfeed['sitemap_cat'].value_counts()
# Out:
# buzzfeed    324033
# shopping     24021
# video        12659
# tasty         3766
# Name: sitemap_cat, dtype: int64

# %%
buzzfeed.rename(columns={'sitemap_cat' : 'URL_Count'}, inplace=True)

# %%
(buzzfeed['URL_Count']
.value_counts()
.to_frame()
.assign(percentage=lambda df: df['URL_Count'].div(df['URL_Count'].sum()))
.style.format(dict(sitemap_cat='{:,}', percentage='{:.1%}')))
# particular site page - like video, cintents, and blog etc...
# Out:
# <style  type="text/css" >
# </style><table id="T_74334384_a297_11eb_ae81_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >URL_Count</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_74334384_a297_11eb_ae81_0242ac1c0002level0_row0" class="row_heading level0 row0" >buzzfeed</th>
#                         <td id="T_74334384_a297_11eb_ae81_0242ac1c0002row0_col0" class="data row0 col0" >324033</td>
#                         <td id="T_74334384_a297_11eb_ae81_0242ac1c0002row0_col1" class="data row0 col1" >88.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_74334384_a297_11eb_ae81_0242ac1c0002level0_row1" class="row_heading level0 row1" >shopping</th>
#                         <td id="T_74334384_a297_11eb_ae81_0242ac1c0002row1_col0" class="data row1 col0" >24021</td>
# ...

# %%
articles_per_year = buzzfeed.resample('A')['loc'].count()
articles_per_year.to_frame()
# Out:
#                               loc
# lastmod
# 2008-12-31 00:00:00+00:00     821
# 2009-12-31 00:00:00+00:00     789
# 2010-12-31 00:00:00+00:00     650
# 2011-12-31 00:00:00+00:00    2172
# 2012-12-31 00:00:00+00:00    6066
# 2013-12-31 00:00:00+00:00   10604
# 2014-12-31 00:00:00+00:00   12001
# 2015-12-31 00:00:00+00:00   37276
# 2016-12-31 00:00:00+00:00   31652
# 2017-12-31 00:00:00+00:00   31739
# 2018-12-31 00:00:00+00:00   29103
# 2019-12-31 00:00:00+00:00   39522
# 2020-12-31 00:00:00+00:00  131651
# 2021-12-31 00:00:00+00:00   17760

# %%
articles_per_month = buzzfeed.resample('M')['loc'].count()
articles_per_month.to_frame()
# Out:
#                             loc
# lastmod
# 2008-01-31 00:00:00+00:00    50
# 2008-02-29 00:00:00+00:00    61
# 2008-03-31 00:00:00+00:00    63
# 2008-04-30 00:00:00+00:00    53
# 2008-05-31 00:00:00+00:00    59
# ...                         ...
# 2020-12-31 00:00:00+00:00  3875
# 2021-01-31 00:00:00+00:00  3416
# 2021-02-28 00:00:00+00:00  5139
# 2021-03-31 00:00:00+00:00  5843
# 2021-04-30 00:00:00+00:00  3362
#
# [160 rows x 1 columns]

# %%
articles_per_day = buzzfeed.resample('D')['loc'].count()
articles_per_day.to_frame()
# Out:
#                            loc
# lastmod
# 2008-01-02 00:00:00+00:00    1
# 2008-01-03 00:00:00+00:00    5
# 2008-01-04 00:00:00+00:00    2
# 2008-01-05 00:00:00+00:00    0
# 2008-01-06 00:00:00+00:00    0
# ...                        ...
# 2021-04-17 00:00:00+00:00  141
# 2021-04-18 00:00:00+00:00  195
# 2021-04-19 00:00:00+00:00  231
# 2021-04-20 00:00:00+00:00  181
# 2021-04-21 00:00:00+00:00   81
#
# [4859 rows x 1 columns]

# %%
fig = go.Figure()

fig.add_bar(x = articles_per_year.index, y = articles_per_year.values, name = 'Post Per Months Bar Plot')
fig.add_scatter(x = articles_per_year.index, y = articles_per_year.values, name = 'Post Per Months Scatter Plot Line')
    
fig.layout.title = 'Post Trends over Years for Buzzfeed'
fig.layout.xaxis.title = 'Years'
fig.layout.yaxis.title = 'Post Count'

fig.update_layout(
    autosize = True,
    width = 1500,
    height = 600,
    paper_bgcolor = 'white',
)

fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="80589618-80aa-43ec-ad46-47384588a9a7" class="plotly-graph-div" style="height:600px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80589618-80aa-43ec-ad46-47384588a9a7")) {
#                     Plotly.newPlot(
#                         '80589618-80aa-43ec-ad46-47384588a9a7',
# ...

# %%
fig = go.Figure()

fig.add_bar(x = articles_per_month.index, y = articles_per_month.values, name = 'Post Per Months Bar Plot')
fig.add_scatter(x = articles_per_month.index, y = articles_per_month.values, name = 'Post Per Months Scatter Plot Line')

fig.layout.title = 'Post Trends over Years for Buzzfeed'
fig.layout.xaxis.title = 'Years'
fig.layout.yaxis.title = 'Post Count'

fig.update_layout(
    autosize = True,
    width = 1500,
    height = 600,
    paper_bgcolor = 'white',
)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="480fd7b8-7e20-4c25-a447-7808808fcacb" class="plotly-graph-div" style="height:600px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("480fd7b8-7e20-4c25-a447-7808808fcacb")) {
#                     Plotly.newPlot(
#                         '480fd7b8-7e20-4c25-a447-7808808fcacb',
# ...

# %%
(buzzfeed
  .groupby(buzzfeed.index.weekday)['loc']
 .count().to_frame()
 .rename(columns=dict(loc='count'))
 .assign(day=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
 .style.bar(color='blue').format(dict(count='{:,}'))
 )
# Out:
# <style  type="text/css" >
# #T_905235e8_a297_11eb_ae81_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 82.5%, transparent 82.5%);
#         }#T_905235e8_a297_11eb_ae81_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 100.0%, transparent 100.0%);
#         }#T_905235e8_a297_11eb_ae81_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 96.7%, transparent 96.7%);
#         }#T_905235e8_a297_11eb_ae81_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 50.9%, transparent 50.9%);
#         }#T_905235e8_a297_11eb_ae81_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
# ...

# %%
from plotly.subplots import make_subplots
categories = buzzfeed['sitemap'].unique()

# %%
buzzfeed['loc'].sample(15).tolist()
# Out:
# ['https://www.buzzfeed.com/mosesmedina/birth-control-around-the-world',
#  'https://www.buzzfeed.com/jpmoore/meet-the-14-year-old-who-is-going-to-play-in-the-m',
#  'https://www.buzzfeed.com/noradominick/tv-moments-of-week-3-26-21',
#  'https://www.buzzfeed.com/jp/natsukoabe/mahoubinshokki',
#  'https://www.buzzfeed.com/annmariealcantara/life-changing-lessons-relationships-can-learn-from-junk-f',
#  'https://www.buzzfeed.com/jarrylee/one-book-two-book-red-book-new-book',
#  'https://www.buzzfeed.com/fr/anaisbordages/ete-le-cauchemar-des-grosses-fesses',
#  'https://www.buzzfeed.com/tanyachen/gwen-stefani-has-finally-blessed-us-with-a-bouncy-new-track',
#  'https://www.buzzfeed.com/mx/artafin110/que-prefieres-de-peliculas-de-terror',
#  'https://www.buzzfeed.com/fjelstud/my-little-racist-three-year-old',
#  'https://www.buzzfeed.com/joyannjeffrey/michelle-williams-gave-someone-a-much-needed-etiquette',
#  'https://www.buzzfeed.com/samimain/this-is-a-diary',
# ...

# %%
# Number of Articles per language
buzzfeed['lang'] = buzzfeed['loc'].str.extract('/([a-z]{2})/')[0].fillna('en')
by_lang = buzzfeed['lang'].value_counts()
by_lang.to_frame().style.format('{:,}')
# Out:
# <style  type="text/css" >
# </style><table id="T_997b62e8_a297_11eb_ae81_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >lang</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_997b62e8_a297_11eb_ae81_0242ac1c0002level0_row0" class="row_heading level0 row0" >en</th>
#                         <td id="T_997b62e8_a297_11eb_ae81_0242ac1c0002row0_col0" class="data row0 col0" >313,031</td>
#             </tr>
#             <tr>
#                         <th id="T_997b62e8_a297_11eb_ae81_0242ac1c0002level0_row1" class="row_heading level0 row1" >jp</th>
#                         <td id="T_997b62e8_a297_11eb_ae81_0242ac1c0002row1_col0" class="data row1 col0" >24,205</td>
#             </tr>
#             <tr>
#                         <th id="T_997b62e8_a297_11eb_ae81_0242ac1c0002level0_row2" class="row_heading level0 row2" >mx</th>
# ...

# %%
fig = go.Figure()
fig.add_bar(x=by_lang.index, y = by_lang.values)
fig.layout.title = 'Buzzfeed Number of Articles per Language'
# fig.layout.paper_bgcolor = '#ESECF6'
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="46ab5e49-345b-46fa-b9c3-f839a7e00507" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("46ab5e49-345b-46fa-b9c3-f839a7e00507")) {
#                     Plotly.newPlot(
#                         '46ab5e49-345b-46fa-b9c3-f839a7e00507',
# ...

# %%
fig = make_subplots(cols=1, rows=len(by_lang), subplot_titles=by_lang.index.str.upper(),
                    shared_xaxes=True, y_title = 'Number of Articles')
for i, lang in enumerate(by_lang):
    df = buzzfeed[buzzfeed['lang']==by_lang.index[i]].resample('M')['loc'].count()
    fig.add_bar(x=df.index, y=df.values, row=i+1, col=1, showlegend=False, name=lang)
fig.layout.height = 800
fig.layout.title = 'Buzzfeed Monthly Article by Language'
fig.layout.paper_bgcolor = '#E5ECF6'
fig.show(config=dict(displayModeBar=False))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="245ad1b5-d8db-4d93-a856-4356bc97b3bb" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("245ad1b5-d8db-4d93-a856-4356bc97b3bb")) {
#                     Plotly.newPlot(
#                         '245ad1b5-d8db-4d93-a856-4356bc97b3bb',
# ...

# %%
buzzfeed['author'] = buzzfeed['loc'].str.split('/').str[-2]
buzzfeed.sample(5)
# Out:
#                                                                          loc  ...            author
# lastmod                                                                       ...
# 2017-06-05 00:00:00+00:00  https://www.buzzfeed.com/patrickstrudwick/a-ni...  ...  patrickstrudwick
# 2012-10-21 00:00:00+00:00  https://www.buzzfeed.com/zekejmiller/embattled...  ...       zekejmiller
# 2015-04-09 00:00:00+00:00  https://www.buzzfeed.com/gyanyankovich/19-vece...  ...     gyanyankovich
# 2018-07-12 00:00:00+00:00  https://www.buzzfeed.com/elliewoodward/chrissy...  ...     elliewoodward
# 2015-09-11 00:00:00+00:00  https://www.buzzfeed.com/jarettwieselman/under...  ...   jarettwieselman
#
# [5 rows x 13 columns]

# %%
print('Number of Authors: ', buzzfeed['author'].nunique(), '\n')
(buzzfeed['author']
 .value_counts()
 .to_frame() 
 .assign(perc=lambda df: df['author'].div(df['author'].sum()),
         cum_perc=lambda df: df['perc'].cumsum())[:20]
 .reset_index()
 .rename(columns=dict(index='author', author='count', perc='%', cum_perc='cum. %'))
 .style.set_caption('Top Authors by Number of Articles')
 .format({'count': '{:,}','%' : '{:.1%}', 'cum.%' : '{:.1%}'})
 .background_gradient(cmap='cividis')
 )
# Out:
# Number of Authors:  3725
# <style  type="text/css" >
# #T_a70314c4_a297_11eb_ae81_0242ac1c0002row0_col1,#T_a70314c4_a297_11eb_ae81_0242ac1c0002row0_col2,#T_a70314c4_a297_11eb_ae81_0242ac1c0002row19_col3{
#             background-color:  #fee838;
#             color:  #000000;
#         }#T_a70314c4_a297_11eb_ae81_0242ac1c0002row0_col3,#T_a70314c4_a297_11eb_ae81_0242ac1c0002row19_col1,#T_a70314c4_a297_11eb_ae81_0242ac1c0002row19_col2{
#             background-color:  #00224e;
#             color:  #f1f1f1;
#         }#T_a70314c4_a297_11eb_ae81_0242ac1c0002row1_col1,#T_a70314c4_a297_11eb_ae81_0242ac1c0002row1_col2{
#             background-color:  #efd748;
#             color:  #000000;
#         }#T_a70314c4_a297_11eb_ae81_0242ac1c0002row1_col3{
#             background-color:  #31436d;
#             color:  #f1f1f1;
#         }#T_a70314c4_a297_11eb_ae81_0242ac1c0002row2_col1,#T_a70314c4_a297_11eb_ae81_0242ac1c0002row2_col2,#T_a70314c4_a297_11eb_ae81_0242ac1c0002row3_col3{
# ...

# %%
def compare_authors_by_year(*authors):
    fig = go.Figure()
    for author in authors:
        df = buzzfeed[buzzfeed['author']==author].resample('A')['loc'].count()
        fig.add_scatter(x=df.index, y= df.values, name=author, mode= 'markers+lines')
        fig.layout.title='Articles per Month by: ' + ', '.join(authors)
        fig.layout.paper_bgcolor = '#E5ECF6'
    return fig


def compare_authors_by_month(*authors):
    fig = go.Figure()
    for author in authors:
        df = buzzfeed[buzzfeed['author']==author].resample('M')['loc'].count()
        fig.add_scatter(x=df.index, y= df.values, name=author, mode= 'markers+lines')
        fig.layout.title='Articles per Month by: ' + ', '.join(authors)
        fig.layout.paper_bgcolor = '#E5ECF6'
    return fig

# %%
compare_authors_by_year('fabordrabfeed', 'mjs538', 'elliewoodward', 'nowthisnews', 'briangalindo','mikespohr','josehernandez','ryanschocket2','andyneuenschwander','ktlincoln')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7dfe8c6c-2668-4221-8386-0ad914514450" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7dfe8c6c-2668-4221-8386-0ad914514450")) {
#                     Plotly.newPlot(
#                         '7dfe8c6c-2668-4221-8386-0ad914514450',
# ...

# %%
compare_authors_by_month('fabordrabfeed', 'mjs538', 'elliewoodward', 'whitneyjefferson', 'nowthisnews','daves4','peggy','briangalindo','jpmoore','luisdelvalle','jennaguillaume','mikespohr','josehernandez','ryanschocket2','elliewoodward','expresident','andyneuenschwander','ktlincoln','mireyagonzalez','zekejmiller','jasminnahar')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="66e41438-4477-4fae-941c-10ed1bc0f673" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("66e41438-4477-4fae-941c-10ed1bc0f673")) {
#                     Plotly.newPlot(
#                         '66e41438-4477-4fae-941c-10ed1bc0f673',
# ...
